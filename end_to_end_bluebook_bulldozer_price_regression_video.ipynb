# %% [markdown]
# <a href="https://colab.research.google.com/github/drpetros11111/FS_DScML_Zero_to_Mastery/blob/Bulldozer/end_to_end_bluebook_bulldozer_price_regression_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚜 Predicting the Sale Price of Bulldozers using Machine Learning
#
# In this notebook, we're going to go through an example machine learning project with the goal of predicting the sale price of bulldozers.
#
# ## 1. Problem defition
#
# > How well can we predict the future sale price of a bulldozer, given its characteristics and previous examples of how much similar bulldozers have been sold for?
#
# ## 2. Data
#
# The data is downloaded from the Kaggle Bluebook for Bulldozers competition: https://www.kaggle.com/c/bluebook-for-bulldozers/data
#
# There are 3 main datasets:
#
# * Train.csv is the training set, which contains data through the end of 2011.
# * Valid.csv is the validation set, which contains data from January 1, 2012 - April 30, 2012 You make predictions on this set throughout the majority of the competition. Your score on this set is used to create the public leaderboard.
# * Test.csv is the test set, which won't be released until the last week of the competition. It contains data from May 1, 2012 - November 2012. Your score on the test set determines your final rank for the competition.
#
# ## 3. Evaluation
#
# The evaluation metric for this competition is the RMSLE (root mean squared log error) between the actual and predicted auction prices.
#
# For more on the evaluation of this project check: https://www.kaggle.com/c/bluebook-for-bulldozers/overview/evaluation
#
# **Note:** The goal for most regression evaluation metrics is to minimize the error. For example, our goal for this project will be to build a machine learning model which minimises RMSLE.
#
# ## 4. Features
#
# Kaggle provides a data dictionary detailing all of the features of the dataset. You can view this data dictionary on Google Sheets: https://docs.google.com/spreadsheets/d/18ly-bLR8sbDJLITkWG7ozKm8l3RyieQ2Fpgix-beSYI/edit?usp=sharing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
# Import training and validation sets
df = pd.read_csv("/content/TrainAndValid.csv",
                 low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  object
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %%
df.columns
# Out:
# Index(['SalesID', 'SalePrice', 'MachineID', 'ModelID', 'datasource',
#        'auctioneerID', 'YearMade', 'MachineHoursCurrentMeter', 'UsageBand',
#        'saledate', 'fiModelDesc', 'fiBaseModel', 'fiSecondaryDesc',
#        'fiModelSeries', 'fiModelDescriptor', 'ProductSize',
#        'fiProductClassDesc', 'state', 'ProductGroup', 'ProductGroupDesc',
#        'Drive_System', 'Enclosure', 'Forks', 'Pad_Type', 'Ride_Control',
#        'Stick', 'Transmission', 'Turbocharged', 'Blade_Extension',
#        'Blade_Width', 'Enclosure_Type', 'Engine_Horsepower', 'Hydraulics',
#        'Pushblock', 'Ripper', 'Scarifier', 'Tip_Control', 'Tire_Size',
#        'Coupler', 'Coupler_System', 'Grouser_Tracks', 'Hydraulics_Flow',
#        'Track_Type', 'Undercarriage_Pad_Width', 'Stick_Length', 'Thumb',
#        'Pattern_Changer', 'Grouser_Type', 'Backhoe_Mounting', 'Blade_Type',
#        'Travel_Controls', 'Differential_Type', 'Steering_Controls'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
ax.scatter(df["saledate"][:1000], df["SalePrice"][:1000])

# %%
df.saledate[:1000]
# Out:
# 0      11/16/2006 0:00
# 1       3/26/2004 0:00
# 2       2/26/2004 0:00
# 3       5/19/2011 0:00
# 4       7/23/2009 0:00
#             ...
# 995     7/16/2009 0:00
# 996     6/14/2007 0:00
# 997     9/22/2005 0:00
# 998     7/28/2005 0:00
# 999     6/16/2011 0:00
# Name: saledate, Length: 1000, dtype: object

# %%
df.saledate.dtype
# Out:
# dtype('O')

# %%
df.SalePrice.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Parsing dates
#
# When we work with time series data, we want to enrich the time & date component as much as possible.
#
# We can do that by telling pandas which of our columns has dates in it using the `parse_dates` parameter.

# %%
# Import data again but this time parse dates
df = pd.read_csv("/content/TrainAndValid.csv",
                 low_memory=False,
                 parse_dates=["saledate"])

# %% [markdown]
# # Import the Data and Parse the Salesdata as Time Series
#
# ----------------------------------
# ##df:
#
# This is the name of the DataFrame where the CSV data will be loaded.
#
# A DataFrame is a two-dimensional, table-like structure in pandas where data is stored in rows and columns.
#
# ---------------------------------
# ##pd.read_csv:
#
# This function reads the data from the CSV file into a DataFrame. The file being read is "TrainAndValid.csv", which is located in the /content/ directory.
#
#     "/content/TrainAndValid.csv":
#
# The file path to the CSV file containing the data.
#
# ----------------------------
# ##low_memory=False:
#
# This parameter is used to control how pandas reads the CSV file.
#
# Setting low_memory=False makes pandas read the file in one go, avoiding issues related to inferring data types in chunks.
#
# It prevents pandas from using less memory by processing the file in smaller chunks, which can sometimes cause type inference problems (e.g., interpreting columns with mixed data types).
#
# -------------------------
# ##parse_dates=["saledate"]:
#
# This tells pandas to parse the "saledate" column as a date.
# Without this, pandas might read this column as a string (text).
#
# When parsing dates, pandas converts the text into datetime objects, which makes it easier to work with dates, perform time-based operations, and analyze trends over time.
#
# ------------------------
# #Summary
#
# This line of code reads a CSV file ("TrainAndValid.csv") into a DataFrame called df, with special handling for:
#
# The "saledate" column, ensuring it is parsed as a date (not just text).
#
# Setting low_memory=False to avoid memory issues and ensure the data types are correctly inferred when reading the file.
#
# Let me know if you'd like more details on any part!

# %%
df.saledate.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.saledate[:1000]
# Out:
# 0     2006-11-16
# 1     2004-03-26
# 2     2004-02-26
# 3     2011-05-19
# 4     2009-07-23
#          ...
# 995   2009-07-16
# 996   2007-06-14
# 997   2005-09-22
# 998   2005-07-28
# 999   2011-06-16
# Name: saledate, Length: 1000, dtype: datetime64[ns]

# %%
fig, ax = plt.subplots()
ax.scatter(df["saledate"][:1000], df["SalePrice"][:1000])

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate  ... Undercarriage_Pad_Width  \
# 0                      68.0       Low 2006-11-16  ...                     NaN
# 1                    4640.0       Low 2004-03-26  ...                     NaN
# 2                    2838.0      High 2004-02-26  ...                     NaN
# 3                    3486.0      High 2011-05-19  ...                     NaN
# 4                     722.0    Medium 2009-07-23  ...                     NaN
#
# ...

# %%
df.head().T
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                  66000.0
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                   3.0
# YearMade                                                      2004
# MachineHoursCurrentMeter                                      68.0
# UsageBand                                                      Low
# saledate                                       2006-11-16 00:00:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# ...

# %%
df.saledate.head(20)
# Out:
# 0    2006-11-16
# 1    2004-03-26
# 2    2004-02-26
# 3    2011-05-19
# 4    2009-07-23
# 5    2008-12-18
# 6    2004-08-26
# 7    2005-11-17
# 8    2009-08-27
# 9    2007-08-09
# 10   2008-08-21
# 11   2006-08-24
# 12   2005-10-20
# 13   2006-01-26
# 14   2006-01-03
# 15   2006-11-16
# 16   2007-06-14
# 17   2010-01-28
# 18   2006-03-09
# 19   2005-11-17
# Name: saledate, dtype: datetime64[ns]

# %% [markdown]
# ### Sort DataFrame by saledate
#
# When working with time series data, it's a good idea to sort it by date.

# %%
# Sort DataFrame in date order
df.sort_values(by=["saledate"], inplace=True, ascending=True)
df.saledate.head(20)
# Out:
# 205615   1989-01-17
# 274835   1989-01-31
# 141296   1989-01-31
# 212552   1989-01-31
# 62755    1989-01-31
# 54653    1989-01-31
# 81383    1989-01-31
# 204924   1989-01-31
# 135376   1989-01-31
# 113390   1989-01-31
# 113394   1989-01-31
# 116419   1989-01-31
# 32138    1989-01-31
# 127610   1989-01-31
# 76171    1989-01-31
# 127000   1989-01-31
# 128130   1989-01-31
# 127626   1989-01-31
# 55455    1989-01-31
# 55454    1989-01-31
# Name: saledate, dtype: datetime64[ns]

# %% [markdown]
# # Sorting the data
# --------------------------
# ##df.sort_values(by=["saledate"], inplace=True, ascending=True):
#
# df.sort_values: This function sorts the DataFrame based on the values in one or more columns.
#
# by=["saledate"]: Specifies the column by which the DataFrame should be sorted. In this case, the DataFrame is being sorted by the "saledate" column.
#
# inplace=True: This ensures that the sorting happens directly on the original DataFrame (df) without needing to create a new DataFrame.
#
# If inplace=False (the default), a new sorted DataFrame would be returned, leaving the original DataFrame unchanged.
#
# ascending=True: This means the DataFrame will be sorted in ascending order (from earliest to latest dates).
#
# If ascending=False, the DataFrame would be sorted in descending order (from latest to earliest dates).
#
# df.saledate.head(20):
#
# df.saledate: This refers to the "saledate" column of the DataFrame.
#
# head(20): This function displays the first 20 rows of the column. By default, .head() shows the first 5 rows, but here, it's been specified to show 20 rows.
#
# -----------------------------
# #Summary
# This code sorts the DataFrame df by the "saledate" column in ascending order and then displays the first 20 dates from the sorted "saledate" column.

# %% [markdown]
# ### Make a copy of the original DataFrame
#
# We make a copy of the original dataframe so when we manipulate the copy, we've still got our original data.

# %%
# Make a copy of the original DataFrame to perform edits on
df_tmp = df.copy()

# %% [markdown]
# ### Add datetime parameters for `saledate` column

# %%
df_tmp["saleYear"] = df_tmp.saledate.dt.year
df_tmp["saleMonth"] = df_tmp.saledate.dt.month
df_tmp["saleDay"] = df_tmp.saledate.dt.day
df_tmp["saleDayOfWeek"] = df_tmp.saledate.dt.dayofweek
df_tmp["saleDayOfYear"] = df_tmp.saledate.dt.dayofyear

# %% [markdown]
# # Extract Features for Analyzing Seasonal Trends or Patterns
# The code you provided extracts various date-related features from the saledate column in the df_tmp DataFrame and creates new columns for each extracted feature. Here's a breakdown of what each line does:
#
#     df_tmp["saleYear"] = df_tmp.saledate.dt.year
#     df_tmp["saleMonth"] = df_tmp.saledate.dt.month
#     df_tmp["saleDay"] = df_tmp.saledate.dt.day
#     df_tmp["saleDayOfWeek"] = df_tmp.saledate.dt.dayofweek
#     df_tmp["saleDayOfYear"] = df_tmp.saledate.dt.dayofyear
#
# ---------------------------
# ##df_tmp["saleYear"] = df_tmp.saledate.dt.year:
#
# This creates a new column called "saleYear" in the df_tmp DataFrame.
# It extracts the year from the saledate column.
#
# The dt accessor is used to work with datetime-like values, and .year gets the year of the sale.
#
# -------------------------------
# ##df_tmp["saleMonth"] = df_tmp.saledate.dt.month:
#
# This creates a new column called "saleMonth".
#
# It extracts the month from the saledate column (values will range from 1 to 12, representing January to December).
#
# -------------------------------
# ##df_tmp["saleDay"] = df_tmp.saledate.dt.day:
#
# This creates a new column called "saleDay".
#
# It extracts the day of the month from the saledate column (values will range from 1 to 31, depending on the month).
#
# ------------------------------------------
# ##df_tmp["saleDayOfWeek"] = df_tmp.saledate.dt.dayofweek:
#
# This creates a new column called "saleDayOfWeek".
#
# It extracts the day of the week from the saledate column, where the value ranges from 0 (Monday) to 6 (Sunday).
#
# -------------------------------
# ##df_tmp["saleDayOfYear"] = df_tmp.saledate.dt.dayofyear:
#
# This creates a new column called "saleDayOfYear".
#
# It extracts the day of the year from the saledate column, where the value ranges from 1 to 365 (or 366 in a leap year), representing which day of the year the sale occurred.
#
# -------------------------------
# #Summary
# Year: Extracted into "saleYear".
#
# Month: Extracted into "saleMonth".
#
# Day: Extracted into "saleDay".
#
# Day of the Week: Extracted into "saleDayOfWeek" (where Monday = 0 and Sunday = 6).
#
# Day of the Year: Extracted into "saleDayOfYear" (values from 1 to 365/366).
# These extracted features can be useful for analyzing seasonal trends or patterns related to sales behavior across different time periods.

# %%
df_tmp.head().T
# Out:
#                                                                      205615  \
# SalesID                                                             1646770
# SalePrice                                                            9500.0
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                           18.0
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# saledate                                                1989-01-17 00:00:00
# fiModelDesc                                                            TD20
# ...

# %%
# Now we've enriched our DataFrame with date time features, we can remove 'saledate'
df_tmp.drop("saledate", axis=1, inplace=True)

# %%
# Check the values of different columns
df_tmp.state.value_counts()
# Out:
# state
# Florida           67320
# Texas             53110
# California        29761
# Washington        16222
# Georgia           14633
# Maryland          13322
# Mississippi       13240
# Ohio              12369
# Illinois          11540
# Colorado          11529
# New Jersey        11156
# North Carolina    10636
# Tennessee         10298
# Alabama           10292
# Pennsylvania      10234
# South Carolina     9951
# Arizona            9364
# New York           8639
# Connecticut        8276
# Minnesota          7885
# Missouri           7178
# Nevada             6932
# Louisiana          6627
# Kentucky           5351
# Maine              5096
# Indiana            4124
# Arkansas           3933
# New Mexico         3631
# Utah               3046
# Unspecified        2801
# Wisconsin          2745
# New Hampshire      2738
# Virginia           2353
# Idaho              2025
# Oregon             1911
# Michigan           1831
# Wyoming            1672
# Montana            1336
# ...

# %%
df_tmp.head()
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 205615  1646770     9500.0    1126363     8434         132          18.0
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
# 212552  1671174    16000.0    1327630     8591         132          99.0
# 62755   1329056    22000.0    1336053     4089         132          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand fiModelDesc  ...  \
# 205615      1974                       NaN       NaN        TD20  ...
# 274835      1980                       NaN       NaN         A66  ...
# 141296      1978                       NaN       NaN         D7G  ...
# 212552      1980                       NaN       NaN         A62  ...
# 62755       1984                       NaN       NaN         D3B  ...
#
#            Backhoe_Mounting Blade_Type      Travel_Controls Differential_Type  \
# ...

# %%
len(df_tmp)
# Out:
# 412698

# %% [markdown]
# ## 5. Modelling
#
# We've done enough EDA (we could always do more) but let's start to do some model-driven EDA.

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              412698 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  412698 non-null  float64
#  8   saleYear                  412698 non-null  int32
#  9   saleMonth                 412698 non-null  int32
#  10  saleDay                   412698 non-null  int32
#  11  saleDayOfWeek             412698 non-null  int32
#  12  saleDayOfYear             412698 non-null  int32
# ...

# %%
# Let's build a machine learning model
from sklearn.ensemble import RandomForestRegressor
import pandas as pd # Make sure you have pandas imported

model = RandomForestRegressor(n_jobs=-1,
                              random_state=42)

# Convert string values to numerical representation if necessary
for col in df_tmp.columns:
    if df_tmp[col].dtype == 'object':
        try:
            # Check if the column contains only numerical strings
            pd.to_numeric(df_tmp[col])
            df_tmp[col] = df_tmp[col].astype(float)
        except ValueError:
            print(f"Column '{col}' could not be converted to float. Check for non-numerical values.")
            # Handle non-numerical values by dropping the column or using other encoding techniques.
            # For example, you can drop the column:
            df_tmp = df_tmp.drop(col, axis=1)
            # Or use one-hot encoding if the column is categorical:
            # df_tmp = pd.get_dummies(df_tmp, columns=[col])

# Impute missing values using the mean
df_tmp = df_tmp.fillna(df_tmp.mean())

model.fit(df_tmp.drop("SalePrice", axis=1), df_tmp["SalePrice"])
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %% [markdown]
# # Random Forest for Linear Regression
#
# ------------------------------------
# ##1. Model Initialization:
#
#     from sklearn.ensemble import RandomForestRegressor
#     import pandas as pd
#     model = RandomForestRegressor(n_jobs=-1, random_state=42)
#
# -------------------------------
# ##RandomForestRegressor:
# This is a machine learning model used for regression tasks. It fits multiple decision trees on different subsets of the data and averages the results to improve accuracy and reduce overfitting.
#
# ##n_jobs=-1:
#
# This allows the model to use all available CPU cores to train the model in parallel, which can speed up training.
#
# ##random_state=42:
#
# This ensures that the results are reproducible by setting a seed for random number generation.
#
# --------------------------------------------------
# ##2. Handling String Columns:
#
#     for col in df_tmp.columns:
#        if df_tmp[col].dtype == 'object':
#           try:
#               pd.to_numeric(df_tmp[col])
#               df_tmp[col] = df_tmp[col].astype(float)
#            except ValueError:
#               print(f"Column '{col}' could not be converted to float. Check for non-numerical values.")
#               df_tmp = df_tmp.drop(col, axis=1)
#
# ###Convert String Columns to Numeric:
#
# The loop goes through each column in df_tmp and checks if its data type is object (i.e., a string).
#
# If the column contains numerical strings (e.g., "123"), it tries to convert them to numeric values using pd.to_numeric().
#
# If successful, the column is converted to a float type.
#
# If the conversion fails (because of non-numerical values), the code drops the column from the DataFrame (or it could alternatively encode the column using techniques like one-hot encoding).
#
# ###Error Handling:
#
# If the column cannot be converted to a float (i.e., it contains non-numeric strings), an error message is printed, and the column is dropped.
#
# Alternatively, you could apply one-hot encoding, which would convert the categorical values into a format that the model can understand.
#
# ---------------------------------------------------
#
# #3. Handling Missing Values:
#
#     df_tmp = df_tmp.fillna(df_tmp.mean())
#
# ##Imputing Missing Values:
#
# This replaces any missing values (NaN) in the DataFrame with the mean value of each column.
#
# This step ensures that the data does not contain any missing values, which could cause issues during model training.
#
# ---------------------------------
# #4. Model Training:
#
#     model.fit(df_tmp.drop("SalePrice", axis=1), df_tmp["SalePrice"])
#
# ##Features and Target Variable:
#
# The target variable (what you want to predict) is "SalePrice", and the features (input data used for prediction) are all the other columns.
#
# ##df_tmp.drop("SalePrice", axis=1):
#
# This removes the "SalePrice" column from df_tmp so that it is not used as a feature in the model.
#
# ##df_tmp["SalePrice"]:
#
# This is the column being predicted (the target variable).
#
# ---------------------------------------------
# ##model.fit():
#
# This method trains the RandomForestRegressor model using the features and target variable.
#
# -----------------------------------
# #Summary of Process:
# Import and initialize a RandomForestRegressor model.
#
# Handle string columns:
#
# Convert numerical strings to floats.
#
# Drop columns with non-numerical strings or encode them.
# Impute missing values by replacing them with the column mean.
#
# Train the model by fitting it to the data, using all features except the target variable (SalePrice).
#
# This code sets up a basic regression model. You can later evaluate the model's performance and optimize it further.

# %%
if 'UsageBand' in df_tmp:
    print(df_tmp["UsageBand"].dtype)
else:
    print("Column 'UsageBand' not found in DataFrame.")
# Out:
# Column 'UsageBand' not found in DataFrame.

# %%
df_tmp.isna().sum()
# Out:
# SalesID                     0
# SalePrice                   0
# MachineID                   0
# ModelID                     0
# datasource                  0
# auctioneerID                0
# YearMade                    0
# MachineHoursCurrentMeter    0
# saleYear                    0
# saleMonth                   0
# saleDay                     0
# saleDayOfWeek               0
# saleDayOfYear               0
# dtype: int64

# %% [markdown]
# ### Convert string to categories
#
# One way we can turn all of our data into numbers is by converting them into pandas catgories.
#
# We can check the different datatypes compatible with pandas here: https://pandas.pydata.org/pandas-docs/stable/reference/general_utility_functions.html#data-types-related-functionality

# %%
df_tmp.head().T
# Out:
#                                 205615        274835        141296  \
# SalesID                   1.646770e+06  1.821514e+06  1.505138e+06
# SalePrice                 9.500000e+03  1.400000e+04  5.000000e+04
# MachineID                 1.126363e+06  1.194089e+06  1.473654e+06
# ModelID                   8.434000e+03  1.015000e+04  4.139000e+03
# datasource                1.320000e+02  1.320000e+02  1.320000e+02
# auctioneerID              1.800000e+01  9.900000e+01  9.900000e+01
# YearMade                  1.974000e+03  1.980000e+03  1.978000e+03
# MachineHoursCurrentMeter  3.522988e+03  3.522988e+03  3.522988e+03
# saleYear                  1.989000e+03  1.989000e+03  1.989000e+03
# saleMonth                 1.000000e+00  1.000000e+00  1.000000e+00
# saleDay                   1.700000e+01  3.100000e+01  3.100000e+01
# saleDayOfWeek             1.000000e+00  1.000000e+00  1.000000e+00
# saleDayOfYear             1.700000e+01  3.100000e+01  3.100000e+01
#
# ...

# %%
# Check if the column exists before trying to access it
if 'UsageBand' in df_tmp.columns:
    # Check the datatype of the column if it exists
    print(pd.api.types.is_string_dtype(df_tmp["UsageBand"]))
else:
    print("Column 'UsageBand' not found in DataFrame.")
# Out:
# Column 'UsageBand' not found in DataFrame.

# %%
# Find the columns which contain strings
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        print(label)

# %% [markdown]
# Identify and Print the names of columns that contain string data. Here's how it works:
#
# Breakdown of the Code:
#
#     for label, content in df_tmp.items():
#        if pd.api.types.is_string_dtype(content):
#           print(label)
#     for label, content in df_tmp.items()::
#
# This loop iterates over each column in the DataFrame df_tmp.
#
# label: The column name (header) of the DataFrame.
#
# content: The actual data (values) contained in the column.
#
# -------------------------------
# ##pd.api.types.is_string_dtype(content):
#
# This function checks if the data type of the content (column) is a string type. Specifically, it returns True if the column contains strings (i.e., dtype is object or string-based).
#
# -------------------------
# ##print(label):
#
# If the column is identified as containing strings, the code prints the name of the column (label).
#
# --------------------------
# ##What It Does:
# For each column in the DataFrame:
#
# It checks whether the column contains string (or text) data.
#
# If it does, the name of that column is printed.
#
# -------------------------
# #Summary
# This code helps you quickly identify which columns in your DataFrame contain string values (such as categorical data or text).
#
# It can be useful for understanding the structure of your dataset, especially if you plan to preprocess or encode those columns before using them in a machine learning model.

# %%
# If you're wondering what df.items() does, here's an example
random_dict = {"key1": "hello",
               "key2": "world!"}

for key, value in random_dict.items():
    print(f"this is a key: {key}",
          f"this is a value: {value}")
# Out:
# this is a key: key1 this is a value: hello
# this is a key: key2 this is a value: world!

# %%
# This will turn all of the string value into category values
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label] = content.astype("category").cat.as_ordered()

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              412698 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  412698 non-null  float64
#  8   saleYear                  412698 non-null  int32
#  9   saleMonth                 412698 non-null  int32
#  10  saleDay                   412698 non-null  int32
#  11  saleDayOfWeek             412698 non-null  int32
#  12  saleDayOfYear             412698 non-null  int32
# ...

# %%
df_tmp.state.cat.categories
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-67cc2d907063> in <cell line: 1>()
# ----> 1 df_tmp.state.cat.categories
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'state'

# %%
# Check for spelling errors in the column name
# and make sure that it exists in the DataFrame.
# If the column name is incorrect, correct it in the code below.

# This will turn all of the string value into category values
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label] = content.astype("category").cat.as_ordered()

# Verify that the column was converted to a categorical type.
df_tmp.info()

# Try accessing the categories again with the correct column name.
# Replace '<column_name>' with a valid column name from df_tmp
# The example below uses 'SaleID', which is a column in the DataFrame
df_tmp['SaleID'].cat.categories
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              412698 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  412698 non-null  float64
#  8   saleYear                  412698 non-null  int32
#  9   saleMonth                 412698 non-null  int32
#  10  saleDay                   412698 non-null  int32
#  11  saleDayOfWeek             412698 non-null  int32
#  12  saleDayOfYear             412698 non-null  int32
# ...

# %%
# Check for spelling errors in the column name
# and make sure that it exists in the DataFrame.
# If the column name is incorrect, correct it in the code below.

# This will turn all of the string value into category values
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label] = content.astype("category").cat.as_ordered()

# Verify that the column was converted to a categorical type.
df_tmp.info()

# Try accessing the categories again with the correct column name.
# Replace '<column_name>' with a valid column name from df_tmp
# The example below uses 'SalesID', which is a column in the DataFrame
df_tmp['SalesID'].cat.categories
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              412698 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  412698 non-null  float64
#  8   saleYear                  412698 non-null  int32
#  9   saleMonth                 412698 non-null  int32
#  10  saleDay                   412698 non-null  int32
#  11  saleDayOfWeek             412698 non-null  int32
#  12  saleDayOfYear             412698 non-null  int32
# ...

# %%
# Check for spelling errors in the column name
# and make sure that it exists in the DataFrame.
# If the column name is incorrect, correct it in the code below.

# This will turn all of the string value into category values
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label] = content.astype("category").cat.as_ordered()

# Verify that the column was converted to a categorical type.
df_tmp.info()

# Try accessing the categories again with the correct column name.
# Replace '<column_name>' with a valid column name from df_tmp
# The example below uses 'SaleID', which is a column in the DataFrame and was
# previously converted to category type
df_tmp['SaleID'].cat.categories
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 412698 entries, 205615 to 409203
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              412698 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  412698 non-null  float64
#  8   saleYear                  412698 non-null  int32
#  9   saleMonth                 412698 non-null  int32
#  10  saleDay                   412698 non-null  int32
#  11  saleDayOfWeek             412698 non-null  int32
#  12  saleDayOfYear             412698 non-null  int32
# ...

# %%
df_tmp.state.cat.codes
# Out:
# 205615    43
# 274835     8
# 141296     8
# 212552     8
# 62755      8
#           ..
# 410879     4
# 412476     4
# 411927     4
# 407124     4
# 409203     4
# Length: 412698, dtype: int8

# %% [markdown]
# Thanks to pandas Categories we now have a way to access all of our data in the form of numbers.
#
# But we still have a bunch of missing data...

# %%
# Check missing data
df_tmp.isnull().sum()/len(df_tmp)
# Out:
# SalesID                     0.000000
# SalePrice                   0.000000
# MachineID                   0.000000
# ModelID                     0.000000
# datasource                  0.000000
# auctioneerID                0.048791
# YearMade                    0.000000
# MachineHoursCurrentMeter    0.642586
# UsageBand                   0.821492
# fiModelDesc                 0.000000
# fiBaseModel                 0.000000
# fiSecondaryDesc             0.340993
# fiModelSeries               0.857845
# fiModelDescriptor           0.818715
# ProductSize                 0.524851
# fiProductClassDesc          0.000000
# state                       0.000000
# ProductGroup                0.000000
# ProductGroupDesc            0.000000
# Drive_System                0.740520
# Enclosure                   0.000809
# Forks                       0.520921
# Pad_Type                    0.803498
# Ride_Control                0.629928
# Stick                       0.803498
# ...

# %% [markdown]
# ### Save preprocessed data

# %%
# Export current tmp dataframe
df_tmp.to_csv("data/bluebook-for-bulldozers/train_tmp.csv",
              index=False)

# %%
# Import preprocessed data
df_tmp = pd.read_csv("data/bluebook-for-bulldozers/train_tmp.csv",
                     low_memory=False)
df_tmp.head().T
# Out:
#                                                                           0  \
# SalesID                                                             1646770
# SalePrice                                                              9500
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                             18
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# fiModelDesc                                                            TD20
# fiBaseModel                                                            TD20
# ...

# %%
df_tmp.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# Turbocharged                331602
# ...

# %% [markdown]
# ## Fill missing values
#
# ### Fill numerical missing values first

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# SalesID
# SalePrice
# MachineID
# ModelID
# datasource
# auctioneerID
# YearMade
# MachineHoursCurrentMeter
# saleYear
# saleMonth
# saleDay
# saleDayOfWeek
# saleDayOfYear

# %%
df_tmp.ModelID
# Out:
# 0          8434
# 1         10150
# 2          4139
# 3          8591
# 4          4089
#           ...
# 412693     5266
# 412694    19330
# 412695    17244
# 412696     3357
# 412697     4701
# Name: ModelID, Length: 412698, dtype: int64

# %%
# Check for which numeric columns have null values
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
# Out:
# auctioneerID
# MachineHoursCurrentMeter

# %%
# Fill numeric rows with the median
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            # Add a binary column which tells us if the data was missing or not
            df_tmp[label+"_is_missing"] = pd.isnull(content)
            # Fill missing numeric values with median
            df_tmp[label] = content.fillna(content.median())

# %%
# Demonstrate how median is more robust than mean
hundreds = np.full((1000,), 100)
hundreds_billion = np.append(hundreds, 1000000000)
np.mean(hundreds), np.mean(hundreds_billion), np.median(hundreds), np.median(hundreds_billion)
# Out:
# (100.0, 999100.8991008991, 100.0, 100.0)

# %%
# Check if there's any null numeric values
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)

# %%
# Check to see how many examples were missing
df_tmp.auctioneerID_is_missing.value_counts()
# Out:
# False    392562
# True      20136
# Name: auctioneerID_is_missing, dtype: int64

# %%
df_tmp.isna().sum()
# Out:
# SalesID                                     0
# SalePrice                                   0
# MachineID                                   0
# ModelID                                     0
# datasource                                  0
# auctioneerID                                0
# YearMade                                    0
# MachineHoursCurrentMeter                    0
# UsageBand                              339028
# fiModelDesc                                 0
# fiBaseModel                                 0
# fiSecondaryDesc                        140727
# fiModelSeries                          354031
# fiModelDescriptor                      337882
# ProductSize                            216605
# fiProductClassDesc                          0
# state                                       0
# ProductGroup                                0
# ProductGroupDesc                            0
# Drive_System                           305611
# ...

# %% [markdown]
# ### Filling and turning categorical variables into numbers

# %%
# Check for columns which aren't numeric
for label, content in df_tmp.items():
    if not pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# UsageBand
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
# Turn categorical variables into numbers and fill missing
for label, content in df_tmp.items():
    if not pd.api.types.is_numeric_dtype(content):
        # Add binary column to indicate whether sample had missing value
        df_tmp[label+"_is_missing"] = pd.isnull(content)
        # Turn categories into numbers and add +1
        df_tmp[label] = pd.Categorical(content).codes+1

# %%
pd.Categorical(df_tmp["state"]).codes+1
# Out:
# array([44,  9,  9, ...,  5,  5,  5], dtype=int8)

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Columns: 103 entries, SalesID to Steering_Controls_is_missing
# dtypes: bool(46), float64(3), int16(4), int64(10), int8(40)
# memory usage: 77.9 MB

# %%
df_tmp.head().T
# Out:
#                                     0        1        2        3        4
# SalesID                       1646770  1821514  1505138  1671174  1329056
# SalePrice                        9500    14000    50000    16000    22000
# MachineID                     1126363  1194089  1473654  1327630  1336053
# ModelID                          8434    10150     4139     8591     4089
# datasource                        132      132      132      132      132
# ...                               ...      ...      ...      ...      ...
# Backhoe_Mounting_is_missing     False     True    False     True    False
# Blade_Type_is_missing           False     True    False     True    False
# Travel_Controls_is_missing      False     True    False     True    False
# Differential_Type_is_missing     True    False     True    False     True
# Steering_Controls_is_missing     True    False     True    False     True
#
# [103 rows x 5 columns]

# %%
df_tmp.isna().sum()
# Out:
# SalesID                         0
# SalePrice                       0
# MachineID                       0
# ModelID                         0
# datasource                      0
#                                ..
# Backhoe_Mounting_is_missing     0
# Blade_Type_is_missing           0
# Travel_Controls_is_missing      0
# Differential_Type_is_missing    0
# Steering_Controls_is_missing    0
# Length: 103, dtype: int64

# %% [markdown]
# Now that all of data is numeric as well as our dataframe has no missing values, we should be able to build a machine learning model.

# %%
df_tmp.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1646770     9500.0    1126363     8434         132          18.0      1974
# 1  1821514    14000.0    1194089    10150         132          99.0      1980
# 2  1505138    50000.0    1473654     4139         132          99.0      1978
# 3  1671174    16000.0    1327630     8591         132          99.0      1980
# 4  1329056    22000.0    1336053     4089         132          99.0      1984
#
#    MachineHoursCurrentMeter  UsageBand  fiModelDesc  ...  \
# 0                       0.0          0         4593  ...
# 1                       0.0          0         1820  ...
# 2                       0.0          0         2348  ...
# 3                       0.0          0         1819  ...
# 4                       0.0          0         2119  ...
#
#    Undercarriage_Pad_Width_is_missing  Stick_Length_is_missing  \
# 0                                True                     True
# ...

# %%
len(df_tmp)
# Out:
# 412698

# %%
# %%time
# Instantiate model
model = RandomForestRegressor(n_jobs=-1,
                              random_state=42)

# Fit the model
model.fit(df_tmp.drop("SalePrice", axis=1), df_tmp["SalePrice"])
# Out:
# CPU times: user 21min 9s, sys: 16.6 s, total: 21min 25s
# Wall time: 6min 58s
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
# Score the model
model.score(df_tmp.drop("SalePrice", axis=1), df_tmp["SalePrice"])
# Out:
# 0.9875468079970563

# %% [markdown]
# **Question:** Why doesn't the above metric hold water? (why isn't the metric reliable)

# %% [markdown]
# ### Splitting data into train/validation sets

# %%
df_tmp.saleYear
# Out:
# 0         1989
# 1         1989
# 2         1989
# 3         1989
# 4         1989
#           ...
# 412693    2012
# 412694    2012
# 412695    2012
# 412696    2012
# 412697    2012
# Name: saleYear, Length: 412698, dtype: int64

# %%
df_tmp.saleYear.value_counts()
# Out:
# 2009    43849
# 2008    39767
# 2011    35197
# 2010    33390
# 2007    32208
# 2006    21685
# 2005    20463
# 2004    19879
# 2001    17594
# 2000    17415
# 2002    17246
# 2003    15254
# 1998    13046
# 1999    12793
# 2012    11573
# 1997     9785
# 1996     8829
# 1995     8530
# 1994     7929
# 1993     6303
# 1992     5519
# 1991     5109
# 1989     4806
# 1990     4529
# Name: saleYear, dtype: int64

# %%
# Split data into training and validation
df_val = df_tmp[df_tmp.saleYear == 2012]
df_train = df_tmp[df_tmp.saleYear != 2012]

len(df_val), len(df_train)
# Out:
# (11573, 401125)

# %%
# Split data into X & y
X_train, y_train = df_train.drop("SalePrice", axis=1), df_train.SalePrice
X_valid, y_valid = df_val.drop("SalePrice", axis=1), df_val.SalePrice

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((401125, 102), (401125,), (11573, 102), (11573,))

# %%
y_train
# Out:
# 0          9500.0
# 1         14000.0
# 2         50000.0
# 3         16000.0
# 4         22000.0
#            ...
# 401120    29000.0
# 401121    11000.0
# 401122    11000.0
# 401123    18000.0
# 401124    13500.0
# Name: SalePrice, Length: 401125, dtype: float64

# %% [markdown]
# ### Building an evaluation function

# %%
# Create evaluation function (the competition uses RMSLE)
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, r2_score

def rmsle(y_test, y_preds):
    """
    Caculates root mean squared log error between predictions and
    true labels.
    """
    return np.sqrt(mean_squared_log_error(y_test, y_preds))

# Create function to evaluate model on a few different levels
def show_scores(model):
    train_preds = model.predict(X_train)
    val_preds = model.predict(X_valid)
    scores = {"Training MAE": mean_absolute_error(y_train, train_preds),
              "Valid MAE": mean_absolute_error(y_valid, val_preds),
              "Training RMSLE": rmsle(y_train, train_preds),
              "Valid RMSLE": rmsle(y_valid, val_preds),
              "Training R^2": r2_score(y_train, train_preds),
              "Valid R^2": r2_score(y_valid, val_preds)}
    return scores

# %% [markdown]
# ## Testing our model on a subset (to tune the hyperparameters)

# %%
# # This takes far too long... for experimenting

# %%time
# model = RandomForestRegressor(n_jobs=-1,
#                               random_state=42)

# model.fit(X_train, y_train)

# %%
len(X_train)
# Out:
# 401125

# %%
# Change max_samples value
model = RandomForestRegressor(n_jobs=-1,
                              random_state=42,
                              max_samples=10000)

# %%
# %%time
# Cutting down on the max number of samples each estimator can see improves training time
model.fit(X_train, y_train)
# Out:
# CPU times: user 44.7 s, sys: 1.01 s, total: 45.7 s
# Wall time: 16.6 s
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=10000, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
(X_train.shape[0] * 100) / 1000000
# Out:
# 40.1125

# %%
10000 * 100
# Out:
# 1000000

# %%
show_scores(model)
# Out:
# {'Training MAE': 5561.2988092240585,
#  'Valid MAE': 7177.26365505919,
#  'Training RMSLE': 0.257745378256977,
#  'Valid RMSLE': 0.29362638671089003,
#  'Training R^2': 0.8606658995199189,
#  'Valid R^2': 0.8320374995090507}

# %% [markdown]
# ### Hyerparameter tuning with RandomizedSearchCV

# %%
# %%time
from sklearn.model_selection import RandomizedSearchCV

# Different RandomForestRegressor hyperparameters
rf_grid = {"n_estimators": np.arange(10, 100, 10),
           "max_depth": [None, 3, 5, 10],
           "min_samples_split": np.arange(2, 20, 2),
           "min_samples_leaf": np.arange(1, 20, 2),
           "max_features": [0.5, 1, "sqrt", "auto"],
           "max_samples": [10000]}

# Instantiate RandomizedSearchCV model
rs_model = RandomizedSearchCV(RandomForestRegressor(n_jobs=-1,
                                                    random_state=42),
                              param_distributions=rf_grid,
                              n_iter=2,
                              cv=5,
                              verbose=True)

# Fit the RandomizedSearchCV model
rs_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.6min finished
# CPU times: user 1min, sys: 6.52 s, total: 1min 7s
# Wall time: 1min 49s
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
# ...

# %%
# Find the best model hyperparameters
rs_model.best_params_
# Out:
# {'n_estimators': 90,
#  'min_samples_split': 16,
#  'min_samples_leaf': 11,
#  'max_samples': 10000,
#  'max_features': 'auto',
#  'max_depth': 10}

# %%
# Evaluate the RandomizedSearch model
show_scores(rs_model)
# Out:
# {'Training MAE': 6633.714300615716,
#  'Valid MAE': 8074.634589086979,
#  'Training RMSLE': 0.2967133662928448,
#  'Valid RMSLE': 0.32142476459239144,
#  'Training R^2': 0.807156908286598,
#  'Valid R^2': 0.7827628271827518}

# %% [markdown]
# ### Train a model with the best hyperparamters
#
# **Note:** These were found after 100 iterations of `RandomizedSearchCV`.

# %%
# %%time

# Most ideal hyperparamters
ideal_model = RandomForestRegressor(n_estimators=40,
                                    min_samples_leaf=1,
                                    min_samples_split=14,
                                    max_features=0.5,
                                    n_jobs=-1,
                                    max_samples=None,
                                    random_state=42) # random state so our results are reproducible

# Fit the ideal model
ideal_model.fit(X_train, y_train)
# Out:
# CPU times: user 3min 50s, sys: 2.22 s, total: 3min 52s
# Wall time: 1min 14s
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features=0.5, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=14, min_weight_fraction_leaf=0.0,
#                       n_estimators=40, n_jobs=-1, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
# Scores for ideal_model (trained on all the data)
show_scores(ideal_model)
# Out:
# {'Training MAE': 2952.0893487566345,
#  'Valid MAE': 5959.9235776482565,
#  'Training RMSLE': 0.14457060318530182,
#  'Valid RMSLE': 0.2465443247528795,
#  'Training R^2': 0.9589437998919624,
#  'Valid R^2': 0.8817886038953688}

# %%
# Scores on rs_model (only trained on ~10,000 examples)
show_scores(rs_model)
# Out:
# {'Training MAE': 6633.714300615714,
#  'Valid MAE': 8074.634589086979,
#  'Training RMSLE': 0.2967133662928448,
#  'Valid RMSLE': 0.32142476459239144,
#  'Training R^2': 0.807156908286598,
#  'Valid R^2': 0.7827628271827518}

# %% [markdown]
# ## Make predictions on test data

# %%
# Import the test data
df_test = pd.read_csv("data/bluebook-for-bulldozers/Test.csv",
                      low_memory=False,
                      parse_dates=["saledate"])

df_test.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter UsageBand   saledate fiModelDesc  ...  \
# 0                    3688.0       Low 2012-05-03        580G  ...
# 1                   28555.0      High 2012-05-10         936  ...
# 2                    6038.0    Medium 2012-05-10    EC210BLC  ...
# 3                    8940.0      High 2012-05-10       330CL  ...
# 4                    2286.0       Low 2012-05-10        650K  ...
#
#   Undercarriage_Pad_Width         Stick_Length   Thumb      Pattern_Changer  \
# 0                     NaN                  NaN     NaN                  NaN
# ...

# %%
# Make predictions on the test dataset
test_preds = ideal_model.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-dcaddf54aa59> in <module>
#       1 # Make predictions on the test dataset
# ----> 2 test_preds = ideal_model.predict(df_test)
#
# ~/Desktop/ml-course/bulldozer-price-prediction-project/env/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     764         check_is_fitted(self)
#     765         # Check data
# --> 766         X = self._validate_X_predict(X)
#     767
#     768         # Assign chunk of trees to jobs
#
# ~/Desktop/ml-course/bulldozer-price-prediction-project/env/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     410         check_is_fitted(self)
#     411
# --> 412         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     413
#     414     @property
#
# ...

# %% [markdown]
# ### Preprocessing the data (getting the test dataset in the same format as our training dataset)

# %%
def preprocess_data(df):
    """
    Performs transformations on df and returns transformed df.
    """
    df["saleYear"] = df.saledate.dt.year
    df["saleMonth"] = df.saledate.dt.month
    df["saleDay"] = df.saledate.dt.day
    df["saleDayOfWeek"] = df.saledate.dt.dayofweek
    df["saleDayOfYear"] = df.saledate.dt.dayofyear

    df.drop("saledate", axis=1, inplace=True)

    # Fill the numeric rows with median
    for label, content in df.items():
        if pd.api.types.is_numeric_dtype(content):
            if pd.isnull(content).sum():
                # Add a binary column which tells us if the data was missing or not
                df[label+"_is_missing"] = pd.isnull(content)
                # Fill missing numeric values with median
                df[label] = content.fillna(content.median())

        # Filled categorical missing data and turn categories into numbers
        if not pd.api.types.is_numeric_dtype(content):
            df[label+"_is_missing"] = pd.isnull(content)
            # We add +1 to the category code because pandas encodes missing categories as -1
            df[label] = pd.Categorical(content).codes+1

    return df

# %%
# Process the test data
df_test = preprocess_data(df_test)
df_test.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 0                    3688.0          2          499          180  ...
# 1                   28555.0          1          831          292  ...
# 2                    6038.0          3         1177          404  ...
# 3                    8940.0          1          287          113  ...
# 4                    2286.0          2          566          196  ...
#
#    Undercarriage_Pad_Width_is_missing  Stick_Length_is_missing  \
# 0                                True                     True
# ...

# %%
# Make predictions on updated test data
test_preds = ideal_model.predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-816969861579> in <module>
#       1 # Make predictions on updated test data
# ----> 2 test_preds = ideal_model.predict(df_test)
#
# ~/Desktop/ml-course/bulldozer-price-prediction-project/env/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     764         check_is_fitted(self)
#     765         # Check data
# --> 766         X = self._validate_X_predict(X)
#     767
#     768         # Assign chunk of trees to jobs
#
# ~/Desktop/ml-course/bulldozer-price-prediction-project/env/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     410         check_is_fitted(self)
#     411
# --> 412         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     413
#     414     @property
#
# ...

# %%
X_train.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1646770    1126363     8434         132          18.0      1974
# 1  1821514    1194089    10150         132          99.0      1980
# 2  1505138    1473654     4139         132          99.0      1978
# 3  1671174    1327630     8591         132          99.0      1980
# 4  1329056    1336053     4089         132          99.0      1984
#
#    MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 0                       0.0          0         4593         1744  ...
# 1                       0.0          0         1820          559  ...
# 2                       0.0          0         2348          713  ...
# 3                       0.0          0         1819          558  ...
# 4                       0.0          0         2119          683  ...
#
#    Undercarriage_Pad_Width_is_missing  Stick_Length_is_missing  \
# 0                                True                     True
# ...

# %%
# We can find how the columns differ using sets
set(X_train.columns) - set(df_test.columns)
# Out:
# {'auctioneerID_is_missing'}

# %%
# Manually adjust df_test to have auctioneerID_is_missing column
df_test["auctioneerID_is_missing"] = False
df_test.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1227829    1006309     3168         121             3      1999
# 1  1227844    1022817     7271         121             3      1000
# 2  1227847    1031560    22805         121             3      2004
# 3  1227848      56204     1269         121             3      2006
# 4  1227863    1053887    22312         121             3      2005
#
#    MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 0                    3688.0          2          499          180  ...
# 1                   28555.0          1          831          292  ...
# 2                    6038.0          3         1177          404  ...
# 3                    8940.0          1          287          113  ...
# 4                    2286.0          2          566          196  ...
#
#    Stick_Length_is_missing  Thumb_is_missing  Pattern_Changer_is_missing  \
# ...

# %% [markdown]
# Finally now our test dataframe has the same features as our training dataframe, we can make predictions!

# %%
# Make predictions on the test data
test_preds = ideal_model.predict(df_test)

# %%
test_preds
# Out:
# array([20531.51652783, 22264.04045921, 51282.34671809, ...,
#        18321.65196727, 17611.80521904, 29852.76494909])

# %% [markdown]
# We've made some predictions but they're not in the same format Kaggle is asking for: https://www.kaggle.com/c/bluebook-for-bulldozers/overview/evaluation

# %%
# Format predictions into the same format Kaggle is after
df_preds = pd.DataFrame()
df_preds["SalesID"] = df_test["SalesID"]
df_preds["SalesPrice"] = test_preds
df_preds
# Out:
#        SalesID    SalesPrice
# 0      1227829  20531.516528
# 1      1227844  22264.040459
# 2      1227847  51282.346718
# 3      1227848  65866.631916
# 4      1227863  43831.973800
# ...        ...           ...
# 12452  6643171  41054.516218
# 12453  6643173  12797.929101
# 12454  6643184  18321.651967
# 12455  6643186  17611.805219
# 12456  6643196  29852.764949
#
# [12457 rows x 2 columns]

# %%
# Export prediction data
df_preds.to_csv("data/bluebook-for-bulldozers/test_predictions.csv", index=False)

# %% [markdown]
# ### Feature Importance
#
# Feature importance seeks to figure out which different attributes of the data were most importance when it comes to predicting the **target variable** (SalePrice).

# %%
# Find feature importance of our best model
ideal_model.feature_importances_
# Out:
# array([3.30079727e-02, 1.52715011e-02, 4.44266419e-02, 1.66930350e-03,
#        3.40827463e-03, 1.98032942e-01, 3.06598876e-03, 9.89211966e-04,
#        4.26254216e-02, 4.39819885e-02, 6.57834011e-02, 4.87982047e-03,
#        1.77023545e-02, 1.51661827e-01, 4.72463146e-02, 5.98046758e-03,
#        1.92525933e-03, 1.38661459e-03, 3.31970958e-03, 7.40841782e-02,
#        3.85573293e-04, 3.47964715e-05, 1.05285412e-03, 1.94379916e-04,
#        1.12356708e-03, 2.92594598e-05, 1.66787697e-04, 1.07571980e-02,
#        2.34012553e-03, 1.47095797e-04, 4.61987256e-03, 2.07291008e-03,
#        3.22984240e-03, 2.47485510e-04, 3.24066792e-04, 6.08422262e-03,
#        8.77981683e-04, 1.24406930e-02, 1.68140425e-03, 3.23016003e-06,
#        1.35047921e-03, 1.18107964e-03, 3.00274447e-03, 5.52631517e-04,
#        8.46720785e-04, 4.39072244e-04, 2.83743193e-04, 2.17336991e-03,
#        8.57391648e-04, 2.31221822e-04, 1.09379516e-03, 7.44377497e-02,
# ...

# %%
# Helper function for plotting feature importance
def plot_features(columns, importances, n=20):
    df = (pd.DataFrame({"features": columns,
                        "feature_importances": importances})
          .sort_values("feature_importances", ascending=False)
          .reset_index(drop=True))

    # Plot the dataframe
    fig, ax = plt.subplots()
    ax.barh(df["features"][:n], df["feature_importances"][:20])
    ax.set_ylabel("Features")
    ax.set_xlabel("Feature importance")
    ax.invert_yaxis()

# %%
plot_features(X_train.columns, ideal_model.feature_importances_)

# %%
df["Enclosure"].value_counts()
# Out:
# OROPS                  177971
# EROPS                  141769
# EROPS w AC              92601
# EROPS AC                   18
# NO ROPS                     3
# None or Unspecified         2
# Name: Enclosure, dtype: int64

# %% [markdown]
# **Question to finish:** Why might knowing the feature importances of a trained machine learning model be helpful?
#
# **Final challenge/extension:** What other machine learning models could you try on our dataset?
# **Hint:** https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html check out the regression section of this map, or try to look at something like CatBoost.ai or XGBooost.ai.
